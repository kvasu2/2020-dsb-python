# %% [markdown]
# # Regression with Scikit Learn
#
# A regression is a predictive model that looks for a functional relationship between a set of variables (X) and a continuous outcome variable (y).
#
# In other word, given an input array we try to predict a numerical value.
#
# - Pandas Documentation: http://pandas.pydata.org/
# - Scikit Learn Documentation: http://scikit-learn.org/stable/documentation.html
# - Seaborn Documentation: http://seaborn.pydata.org/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Weight - Height dataset

# %%
df = pd.read_csv('../data/weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ### Visualize the dataset

# %%
df.plot(kind='scatter', x='Height', y='Weight', alpha=0.2)
plt.title('Humans');

# %% [markdown]
# ## Seaborn pairplot

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue='Gender');

# %% [markdown]
# ## Linear regression

# %% [markdown]
# ### Features

# %%
# what's the purpose of the next line?
# try to print out df['Height'].values and X
# to figure it out

X = df[['Height']].values

# %% [markdown]
# ### Target

# %%
y = df['Weight'].values

# %% [markdown]
# ### Train/Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
    test_size = 0.3, random_state=0)

# %%
### Fit a Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# ### Regression weights

# %%
print("Slope: %.2f" % model.coef_)
print("Intercept: %.2f" % model.intercept_)
# Out:
# Slope: 7.72
# Intercept: -351.18

# %% [markdown]
# ### Mean square error

# %%
y_pred_test = model.predict(X_test)

# %%
mse = np.mean((y_pred_test - y_test) ** 2)

# %%
print("Residual sum of squares: %.2f" % mse)
# Out:
# Residual sum of squares: 152.22

# %% [markdown]
# ### $R^2$ score

# %%
model.score(X_test, y_test)
# Out:
# 0.8535056083267063

# %% [markdown]
# ### Plot line of best fit with Test set

# %%
X_test
# Out:
# array([[64.72387669],
#        [67.27217066],
#        [74.52097209],
#        ...,
#        [63.77640516],
#        [63.69215661],
#        [64.58685574]])

# %%
x_min  = X_test.min()
x_max  = X_test.max()

x_line = np.linspace(x_min, x_max, 100) # dim 1 array
X_line = np.expand_dims(x_line, 1) # dim 2 array, same values

y_line = model.predict(X_line)
# Out:
# array([ 67.95733477,  69.85779564,  71.7582565 ,  73.65871737,
#         75.55917823,  77.4596391 ,  79.36009996,  81.26056083,
#         83.16102169,  85.06148256,  86.96194342,  88.86240429,
#         90.76286515,  92.66332602,  94.56378688,  96.46424775,
#         98.36470861, 100.26516948, 102.16563034, 104.06609121,
#        105.96655207, 107.86701294, 109.7674738 , 111.66793467,
#        113.56839553, 115.4688564 , 117.36931726, 119.26977813,
#        121.17023899, 123.07069986, 124.97116072, 126.87162159,
#        128.77208245, 130.67254332, 132.57300418, 134.47346505,
#        136.37392591, 138.27438678, 140.17484764, 142.07530851,
#        143.97576937, 145.87623024, 147.7766911 , 149.67715197,
#        151.57761283, 153.4780737 , 155.37853456, 157.27899543,
#        159.17945629, 161.07991716, 162.98037802, 164.88083889,
#        166.78129975, 168.68176062, 170.58222148, 172.48268235,
#        174.38314321, 176.28360408, 178.18406494, 180.08452581,
#        181.98498667, 183.88544754, 185.7859084 , 187.68636927,
#        189.58683013, 191.487291  , 193.38775186, 195.28821273,
#        197.18867359, 199.08913446, 200.98959532, 202.89005619,
#        204.79051705, 206.69097792, 208.59143878, 210.49189965,
#        212.39236051, 214.29282138, 216.19328224, 218.09374311,
#        219.99420397, 221.89466484, 223.7951257 , 225.69558657,
#        227.59604743, 229.4965083 , 231.39696916, 233.29743003,
#        235.19789089, 237.09835176, 238.99881262, 240.89927349,
#        242.79973435, 244.70019522, 246.60065608, 248.50111695,
#        250.40157781, 252.30203868, 254.20249954, 256.10296041])

# %%
plt.scatter(X_test, y_test)
plt.plot(X_line, y_line, color = 'red')
plt.title('Humans')
plt.xlabel('Height (in)')
plt.ylabel('Weight (lbs)');

# %% [markdown]
# ## Exercise 1
#
# In this exercise we extend what we have learned about linear regression to a dataset with more than one feature. Here are the steps to complete it:
# - Load the dataset ../data/housing-data.csv
# - plot the histograms for each feature using `sns.pairplot`. Choose the most appropriate column for `hue`.
# - create 2 variables called X and y: X shall be a matrix with 3 columns (sqft,bdrms,age) and y shall be a vector with 1 column (price)
# - create a linear regression model
# - split the data into train and test with a 20% test size and random state zero
# - train the model on the training set and check its R2 coefficient on training and test set
# - how's your model doing?
# - predict the price of a house of 2000 sqft with 3 bedrooms and 20 years of age

# %% [markdown]
# This dataset contains multiple columns:
# - sqft
# - bdrms
# - age
# - price

# %% [markdown]
# ## Exercise 2
# Let's expand beyond the linear regression.
# - Train a regularized regression model like [`Ridge`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html), [`Lasso`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html) or [any other regression model](http://scikit-learn.org/stable/modules/linear_model.html) on the training dataset and test the score on the test set
# - does regularization improve the score?
# - Try changing the regularization strength alpha
# (You could try several models programmatically and collect all the results in a nice table)
